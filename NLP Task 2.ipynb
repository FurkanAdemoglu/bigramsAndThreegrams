# %%
from nltk.tokenize import word_tokenize
from nltk.util import ngrams
from collections import Counter

sentence = "Recent research has increasingly focused on unsupervised and semi-supervised learning algorithms. Such algorithms can learn from data that has not been hand-annotated with the desired answers or using a combination of annotated and non-annotated data. Generally, this task is much more difficult than supervised learning, and typically produces less accurate results for a given amount of input data. However, there is an enormous amount of non-annotated data available (including, among other things, the entire content of the World Wide Web), which can often make up for the inferior results if the algorithm used has a low enough time complexity to be practical."

tokenized = word_tokenize(sentence)

bigrams = ngrams(tokenized, 2)

bigramsFrequency = Counter(bigrams)

valuesOfBigrams = list(bigramsFrequency.values())

bigramlist = list(bigramsFrequency)

print()

for x in range(0, len(bigramlist)):
    if(valuesOfBigrams[x] > 1):
        print(bigramlist[x], " is used ", valuesOfBigrams[x], " times")

print()
print()
print()

threegrams1 = ngrams(tokenized, 3)
threegramsFrequency1 = Counter(threegrams1)
valuesofThreegrams1 = list(threegramsFrequency1.values())
threegramlist1 = list(threegramsFrequency1)

for x in range(0, len(threegramlist1)):
    if(valuesofThreegrams1[x] > 0):
        print(threegramlist1[x], " is used ", valuesofThreegrams1[x], " times")

print()
# Out:
# ('non-annotated', 'data')  is used  2  times
# ('data', '.')  is used  2  times
# ('amount', 'of')  is used  2  times
#
#
#
# ('Recent', 'research', 'has')  is used  1  times
# ('research', 'has', 'increasingly')  is used  1  times
# ('has', 'increasingly', 'focused')  is used  1  times
# ('increasingly', 'focused', 'on')  is used  1  times
# ('focused', 'on', 'unsupervised')  is used  1  times
# ('on', 'unsupervised', 'and')  is used  1  times
# ('unsupervised', 'and', 'semi-supervised')  is used  1  times
# ('and', 'semi-supervised', 'learning')  is used  1  times
# ('semi-supervised', 'learning', 'algorithms')  is used  1  times
# ('learning', 'algorithms', '.')  is used  1  times
# ('algorithms', '.', 'Such')  is used  1  times
# ('.', 'Such', 'algorithms')  is used  1  times
# ('Such', 'algorithms', 'can')  is used  1  times
# ('algorithms', 'can', 'learn')  is used  1  times
# ('can', 'learn', 'from')  is used  1  times
# ('learn', 'from', 'data')  is used  1  times
# ('from', 'data', 'that')  is used  1  times
# ('data', 'that', 'has')  is used  1  times
# ('that', 'has', 'not')  is used  1  times
# ('has', 'not', 'been')  is used  1  times
# ('not', 'been', 'hand-annotated')  is used  1  times
# ('been', 'hand-annotated', 'with')  is used  1  times
# ('hand-annotated', 'with', 'the')  is used  1  times
# ('with', 'the', 'desired')  is used  1  times
# ('the', 'desired', 'answers')  is used  1  times
# ('desired', 'answers', 'or')  is used  1  times
# ('answers', 'or', 'using')  is used  1  times
# ('or', 'using', 'a')  is used  1  times
# ('using', 'a', 'combination')  is used  1  times
# ('a', 'combination', 'of')  is used  1  times
# ('combination', 'of', 'annotated')  is used  1  times
# ('of', 'annotated', 'and')  is used  1  times
# ('annotated', 'and', 'non-annotated')  is used  1  times
# ('and', 'non-annotated', 'data')  is used  1  times
# ('non-annotated', 'data', '.')  is used  1  times
# ('data', '.', 'Generally')  is used  1  times
# ('.', 'Generally', ',')  is used  1  times
# ('Generally', ',', 'this')  is used  1  times
# (',', 'this', 'task')  is used  1  times
# ('this', 'task', 'is')  is used  1  times
# ('task', 'is', 'much')  is used  1  times
# ('is', 'much', 'more')  is used  1  times
# ('much', 'more', 'difficult')  is used  1  times
# ('more', 'difficult', 'than')  is used  1  times
# ('difficult', 'than', 'supervised')  is used  1  times
# ('than', 'supervised', 'learning')  is used  1  times
# ('supervised', 'learning', ',')  is used  1  times
# ('learning', ',', 'and')  is used  1  times
# (',', 'and', 'typically')  is used  1  times
# ('and', 'typically', 'produces')  is used  1  times
# ('typically', 'produces', 'less')  is used  1  times
# ('produces', 'less', 'accurate')  is used  1  times
# ('less', 'accurate', 'results')  is used  1  times
# ('accurate', 'results', 'for')  is used  1  times
# ('results', 'for', 'a')  is used  1  times
# ('for', 'a', 'given')  is used  1  times
# ('a', 'given', 'amount')  is used  1  times
# ('given', 'amount', 'of')  is used  1  times
# ('amount', 'of', 'input')  is used  1  times
# ('of', 'input', 'data')  is used  1  times
# ('input', 'data', '.')  is used  1  times
# ('data', '.', 'However')  is used  1  times
# ('.', 'However', ',')  is used  1  times
# ('However', ',', 'there')  is used  1  times
# (',', 'there', 'is')  is used  1  times
# ('there', 'is', 'an')  is used  1  times
# ('is', 'an', 'enormous')  is used  1  times
# ('an', 'enormous', 'amount')  is used  1  times
# ('enormous', 'amount', 'of')  is used  1  times
# ('amount', 'of', 'non-annotated')  is used  1  times
# ('of', 'non-annotated', 'data')  is used  1  times
# ('non-annotated', 'data', 'available')  is used  1  times
# ('data', 'available', '(')  is used  1  times
# ('available', '(', 'including')  is used  1  times
# ('(', 'including', ',')  is used  1  times
# ('including', ',', 'among')  is used  1  times
# (',', 'among', 'other')  is used  1  times
# ('among', 'other', 'things')  is used  1  times
# ('other', 'things', ',')  is used  1  times
# ('things', ',', 'the')  is used  1  times
# (',', 'the', 'entire')  is used  1  times
# ('the', 'entire', 'content')  is used  1  times
# ('entire', 'content', 'of')  is used  1  times
# ('content', 'of', 'the')  is used  1  times
# ('of', 'the', 'World')  is used  1  times
# ('the', 'World', 'Wide')  is used  1  times
# ('World', 'Wide', 'Web')  is used  1  times
# ('Wide', 'Web', ')')  is used  1  times
# ('Web', ')', ',')  is used  1  times
# (')', ',', 'which')  is used  1  times
# (',', 'which', 'can')  is used  1  times
# ('which', 'can', 'often')  is used  1  times
# ('can', 'often', 'make')  is used  1  times
# ('often', 'make', 'up')  is used  1  times
# ('make', 'up', 'for')  is used  1  times
# ('up', 'for', 'the')  is used  1  times
# ('for', 'the', 'inferior')  is used  1  times
# ('the', 'inferior', 'results')  is used  1  times
# ('inferior', 'results', 'if')  is used  1  times
# ('results', 'if', 'the')  is used  1  times
# ('if', 'the', 'algorithm')  is used  1  times
# ('the', 'algorithm', 'used')  is used  1  times
# ('algorithm', 'used', 'has')  is used  1  times
# ('used', 'has', 'a')  is used  1  times
# ('has', 'a', 'low')  is used  1  times
# ('a', 'low', 'enough')  is used  1  times
# ('low', 'enough', 'time')  is used  1  times
# ('enough', 'time', 'complexity')  is used  1  times
# ('time', 'complexity', 'to')  is used  1  times
# ('complexity', 'to', 'be')  is used  1  times
# ('to', 'be', 'practical')  is used  1  times
# ('be', 'practical', '.')  is used  1  times
