# %%
import pandas as pd
#df = pd.read_csv('textdene.csv')
f = open("task2_pr2.txt", encoding="utf8")
df=f.read()

# %%
import re
import unicodedata
import nltk
from nltk.corpus import stopwords
from collections import Counter
import matplotlib.pyplot as plt

# %%
def basic_clean(text):
    #words=nltk.word_tokenize(text)
  
    wnl = nltk.stem.WordNetLemmatizer()
    stopwords = nltk.corpus.stopwords.words('turkish'),
    
    
    words = re.sub(r'[^\w\s]', '', text).split()
    return [wnl.lemmatize(word) for word in words if word not in stopwords]

# %%
words = basic_clean(df)

# %%
bigrams=nltk.ngrams(words,2)
bigramsfrequency=Counter(bigrams)
valueofbigram=list(bigramsfrequency.values())
bigramslist=list(bigramsfrequency)

for x in range(0,len(bigramslist)):
    if(valueofbigram[x]>5):
        print(bigramslist[x],"is used",valueofbigram[x],"times")
# Out:
# ('olarak', 'kabul') is used 9 times
# ('yaklaşık', 'MÖ') is used 11 times
# ('en', 'eski') is used 20 times
# ('Yunan', 'matematiği') is used 6 times
# ('büyük', 'ölçüde') is used 7 times
# ('dahil', 'olmak') is used 7 times
# ('olmak', 'üzere') is used 6 times
# ('hem', 'de') is used 6 times
# ('19', 'yüzyıl') is used 6 times
# ('Bununla', 'birlikte') is used 6 times
# ('Ana', 'madde') is used 7 times
# ('Babil', 'matematiği') is used 6 times
# ('önemli', 'bir') is used 6 times
# ('için', 'bir') is used 8 times
# ('ve', 'bir') is used 6 times
# ('yanı', 'sıra') is used 8 times
# ('olduğu', 'gibi') is used 7 times
# ('bir', 'şekilde') is used 9 times
# ('etmek', 'için') is used 6 times
# ('herhangi', 'bir') is used 6 times
# ('ve', 'bu') is used 8 times
# ('ikinci', 'dereceden') is used 6 times
# ('aynı', 'zamanda') is used 6 times
# ('çözmek', 'için') is used 6 times
# ('Yunan', 'matematiğinin') is used 6 times
# ('olsa', 'da') is used 7 times
# ('önemli', 'ilerlemeler') is used 7 times
# ('daha', 'fazla') is used 7 times
# ('yol', 'açtı') is used 6 times

# %%
threegrams = nltk.ngrams(words, 3)
threegramsfrequency = Counter(threegrams)
valuesofthreegrams = list(threegramsfrequency.values())
threegramlist = list(threegramsfrequency)

for x in range(0, len(threegramlist)):
    if(valuesofthreegrams[x] > 5):
        print(threegramlist[x], " is used ", valuesofthreegrams[x], " times")
# Out:
# ('dahil', 'olmak', 'üzere')  is used  6  times

# %%
#(pd.Series(nltk.ngrams(words, 2)).value_counts()>1)

# %%
#(pd.Series(nltk.ngrams(words, 3)).value_counts())[:10]

# %%
bigrams_series = (pd.Series(nltk.ngrams(words, 2)).value_counts())[:12]
trigrams_series = (pd.Series(nltk.ngrams(words, 3)).value_counts())[:12]

# %%
trigrams_series.sort_values().plot.barh(color='blue', width=.9, figsize=(12, 8))

# %%
bigrams_series.sort_values().plot.barh(color='blue', width=.9, figsize=(12, 8))
plt.title('20 Most Frequently Occuring Bigrams')
plt.ylabel('Bigram')
plt.xlabel('# of Occurances')
# Out:
# Text(0.5, 0, '# of Occurances')
